# %%
import pandas as pd
import matplotlib as plt
# Out:
# /tmp/ipykernel_241/539419080.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import mudata as md
from mudata import MuData

# %%
data_dir = "/mnt/shared/inference/"

# %%
gasperini_mini_input = md.read_h5mu(data_dir + "gasperini_inference_input_minimal.h5mu")
gasperini_mini_output = md.read_h5mu(data_dir + "gasperini_inference_output_minimal.h5mu")
# Out:
# /opt/conda/lib/python3.11/site-packages/anndata/_core/anndata.py:522: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/anndata/_core/anndata.py:522: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/anndata/_core/anndata.py:522: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/anndata/_core/anndata.py:522: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(

# %%
gasperini_mini_input
# Out:
# MuData object with n_obs × n_vars = 9704 × 167
#   uns:	'pairs_to_test'
#   2 modalities
#     gene:	9704 x 112
#     guide:	9704 x 55
#       var:	'targeting', 'intended_target_name'
#       uns:	'capture_method', 'moi'
#       layers:	'guide_assignment'

# %%
gasperini_mini_input.uns
# Out:
# {'pairs_to_test': {'gene_id': array(['ENSG00000187109', 'ENSG00000114850', 'ENSG00000134851',
#          'ENSG00000163866', 'ENSG00000181610', 'ENSG00000113552',
#          'ENSG00000012660', 'ENSG00000143321', 'ENSG00000122644',
#          'ENSG00000072274', 'ENSG00000106992', 'ENSG00000135046',
#          'ENSG00000165702', 'ENSG00000136929', 'ENSG00000136938',
#          'ENSG00000147454', 'ENSG00000148290', 'ENSG00000136856',
#          'ENSG00000136854', 'ENSG00000107372', 'ENSG00000136937',
#          'ENSG00000198870', 'ENSG00000107290', 'ENSG00000120896',
#          'ENSG00000177125', 'ENSG00000148290', 'ENSG00000119514',
#          'ENSG00000167114', 'ENSG00000136908', 'ENSG00000167106',
#          'ENSG00000136877', 'ENSG00000148300', 'ENSG00000104689',
#          'ENSG00000136925', 'ENSG00000095383', 'ENSG00000167113',
#          'ENSG00000167112', 'ENSG00000120913', 'ENSG00000196312',
#          'ENSG00000119392', 'ENSG00000136842', 'ENSG00000160408',
# ...

# %%
gasperini_mini_input["guide"].obs
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
gasperini_mini_input["guide"].var
# Out:
#                      targeting intended_target_name
# ATGTAGAAGGAGACACCGGG      TRUE      ENSG00000012660
# GCGCAGAGGCGGATGTAGAG      TRUE      ENSG00000012660
# AGAGCGTCGGGATATCGGGG      TRUE      ENSG00000072274
# CTCAGAGCGTCGGGATATCG      TRUE      ENSG00000072274
# GCCCTGCTACCCACTTACAG      TRUE      ENSG00000113552
# GGGAGGCGTCCGTGTAAGTG      TRUE      ENSG00000113552
# GCTCCGCCATGGCTCCTAAG      TRUE      ENSG00000114850
# GGAGCTGCAGGCGAGAACAG      TRUE      ENSG00000114850
# ACCCAGACTCCAGATCGGGG      TRUE      ENSG00000122644
# TGCCGGGCGAGCACCGTTAG      TRUE      ENSG00000122644
# CGGCGCCCGTCCTCTCCGGG      TRUE      ENSG00000134851
# GCTCGGCGCCCGTCCTCTCG      TRUE      ENSG00000134851
# CCCGCGCGCCGCACGGACGG      TRUE      ENSG00000143321
# GCGGATCGGGGCAAGGCTCG      TRUE      ENSG00000143321
# CGGAAGTCGCCGCACCCAGG      TRUE      ENSG00000163866
# GAGAGAGCCGGCGGCCAGTG      TRUE      ENSG00000163866
# ACCAGGCGCAGATCATGGCG      TRUE      ENSG00000181610
# ...

# %%
gasperini_mini_input["guide"].uns
# Out:
# {'capture_method': array(['CROP-seq'], dtype=object),
#  'moi': array(['high'], dtype=object)}

# %%
gasperini_mini_input["guide"].layers["guide_assignment"]
# Out:
# <9704x55 sparse matrix of type '<class 'numpy.float64'>'
# 	with 10563 stored elements in Compressed Sparse Row format>

# %%
gasperini_mini_input["gene"].obs
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
gasperini_mini_input["gene"].var
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
gasperini_mini_output
# Out:
# MuData object with n_obs × n_vars = 9704 × 167
#   uns:	'pairs_to_test', 'test_results'
#   2 modalities
#     gene:	9704 x 112
#     guide:	9704 x 55
#       var:	'targeting', 'intended_target_name'
#       uns:	'capture_method', 'moi'
#       layers:	'guide_assignment'

# %%
gasperini_mini_output.uns
# Out:
# {'pairs_to_test': {'gene_id': array(['ENSG00000187109', 'ENSG00000114850', 'ENSG00000134851',
#          'ENSG00000163866', 'ENSG00000181610', 'ENSG00000113552',
#          'ENSG00000012660', 'ENSG00000143321', 'ENSG00000122644',
#          'ENSG00000072274', 'ENSG00000106992', 'ENSG00000135046',
#          'ENSG00000165702', 'ENSG00000136929', 'ENSG00000136938',
#          'ENSG00000147454', 'ENSG00000148290', 'ENSG00000136856',
#          'ENSG00000136854', 'ENSG00000107372', 'ENSG00000136937',
#          'ENSG00000198870', 'ENSG00000107290', 'ENSG00000120896',
#          'ENSG00000177125', 'ENSG00000148290', 'ENSG00000119514',
#          'ENSG00000167114', 'ENSG00000136908', 'ENSG00000167106',
#          'ENSG00000136877', 'ENSG00000148300', 'ENSG00000104689',
#          'ENSG00000136925', 'ENSG00000095383', 'ENSG00000167113',
#          'ENSG00000167112', 'ENSG00000120913', 'ENSG00000196312',
#          'ENSG00000119392', 'ENSG00000136842', 'ENSG00000160408',
# ...

# %%
gasperini_mini_output["guide"].obs
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
gasperini_mini_output["guide"].var
# Out:
#                      targeting intended_target_name
# ATGTAGAAGGAGACACCGGG      TRUE      ENSG00000012660
# GCGCAGAGGCGGATGTAGAG      TRUE      ENSG00000012660
# AGAGCGTCGGGATATCGGGG      TRUE      ENSG00000072274
# CTCAGAGCGTCGGGATATCG      TRUE      ENSG00000072274
# GCCCTGCTACCCACTTACAG      TRUE      ENSG00000113552
# GGGAGGCGTCCGTGTAAGTG      TRUE      ENSG00000113552
# GCTCCGCCATGGCTCCTAAG      TRUE      ENSG00000114850
# GGAGCTGCAGGCGAGAACAG      TRUE      ENSG00000114850
# ACCCAGACTCCAGATCGGGG      TRUE      ENSG00000122644
# TGCCGGGCGAGCACCGTTAG      TRUE      ENSG00000122644
# CGGCGCCCGTCCTCTCCGGG      TRUE      ENSG00000134851
# GCTCGGCGCCCGTCCTCTCG      TRUE      ENSG00000134851
# CCCGCGCGCCGCACGGACGG      TRUE      ENSG00000143321
# GCGGATCGGGGCAAGGCTCG      TRUE      ENSG00000143321
# CGGAAGTCGCCGCACCCAGG      TRUE      ENSG00000163866
# GAGAGAGCCGGCGGCCAGTG      TRUE      ENSG00000163866
# ACCAGGCGCAGATCATGGCG      TRUE      ENSG00000181610
# ...

# %%
print(gasperini_mini_output["guide"].X)
# Out:
#   (0, 4)	9.0
#   (1, 15)	18.0
#   (2, 53)	24.0
#   (3, 14)	26.0
#   (4, 36)	12.0
#   (5, 9)	34.0
#   (6, 8)	24.0
#   (7, 47)	27.0
#   (7, 50)	1.0
#   (8, 0)	18.0
#   (9, 50)	6.0
#   (10, 39)	50.0
#   (11, 12)	31.0
#   (11, 46)	9.0
#   (12, 25)	5.0
#   (13, 45)	24.0
#   (14, 9)	9.0
#   (14, 39)	5.0
#   (15, 2)	34.0
#   (15, 5)	1.0
#   (16, 50)	15.0
#   (17, 41)	23.0
#   (18, 52)	14.0
#   (19, 4)	29.0
#   (20, 18)	18.0
#   :	:
#   (9687, 32)	31.0
#   (9688, 5)	31.0
#   (9689, 7)	33.0
#   (9690, 21)	5.0
#   (9690, 28)	19.0
#   (9691, 10)	1.0
#   (9691, 19)	1.0
#   (9691, 44)	28.0
#   (9692, 20)	21.0
#   (9692, 21)	1.0
#   (9693, 11)	6.0
#   (9693, 14)	1.0
#   (9694, 49)	11.0
#   (9695, 31)	10.0
#   (9695, 33)	3.0
#   (9695, 37)	1.0
#   (9696, 32)	34.0
#   (9696, 51)	1.0
#   (9697, 35)	21.0
#   (9698, 16)	6.0
#   (9699, 54)	5.0
#   (9700, 24)	39.0
#   (9701, 49)	21.0
#   (9702, 18)	73.0
#   (9703, 28)	12.0

# %%
print(gasperini_mini_output["gene"].X)
# Out:
#   (0, 1)	2.0
#   (0, 6)	2.0
#   (0, 7)	7.0
#   (0, 8)	1.0
#   (0, 17)	1.0
#   (0, 21)	1.0
#   (0, 22)	1.0
#   (0, 23)	12.0
#   (0, 35)	15.0
#   (0, 36)	2.0
#   (0, 37)	1.0
#   (0, 38)	2.0
#   (0, 46)	1.0
#   (0, 48)	1.0
#   (0, 49)	1.0
#   (0, 54)	2.0
#   (0, 57)	1.0
#   (0, 58)	3.0
#   (0, 59)	2.0
#   (0, 60)	1.0
#   (0, 65)	6.0
#   (0, 67)	9.0
#   (0, 68)	1.0
#   (0, 72)	77.0
#   (0, 75)	1.0
#   :	:
#   (9702, 109)	3.0
#   (9702, 110)	9.0
#   (9703, 3)	1.0
#   (9703, 7)	7.0
#   (9703, 8)	1.0
#   (9703, 12)	1.0
#   (9703, 17)	2.0
#   (9703, 23)	10.0
#   (9703, 35)	4.0
#   (9703, 48)	2.0
#   (9703, 65)	2.0
#   (9703, 67)	2.0
#   (9703, 71)	2.0
#   (9703, 72)	51.0
#   (9703, 80)	1.0
#   (9703, 85)	40.0
#   (9703, 98)	3.0
#   (9703, 100)	2.0
#   (9703, 101)	3.0
#   (9703, 103)	6.0
#   (9703, 105)	3.0
#   (9703, 107)	2.0
#   (9703, 108)	1.0
#   (9703, 109)	1.0
#   (9703, 110)	19.0

# %%
papalexi_mini_output = md.read_h5mu(data_dir + "papalexi_inference_output_minimal.h5mu")
# Out:
# /opt/conda/lib/python3.11/site-packages/anndata/_core/anndata.py:522: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/anndata/_core/anndata.py:522: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(

# %%
papalexi_mini_output
# Out:
# MuData object with n_obs × n_vars = 7108 × 406
#   uns:	'pairs_to_test', 'test_results'
#   2 modalities
#     gene:	7108 x 299
#     guide:	7108 x 107
#       var:	'targeting', 'intended_target_name'
#       uns:	'capture_method', 'moi'
#       layers:	'guide_assignment'

# %%
papalexi_mini_output.uns
# Out:
# {'pairs_to_test': {'gene_id': array(['JAK2', 'STAT1', 'IFNGR2', 'CMTM6', 'STAT2', 'STAT3', 'UBE2L6',
#          'TNFRSF14', 'NFKBIA', 'METTL17', 'SKA2', 'DHX29', 'JAK2', 'NAPA',
#          'STAT3', 'MT-CYB', 'AMPD3', 'RAB13', 'NFKBIA', 'ERGIC3',
#          'RP4-756G23.5', 'LRG1', 'STAT1', 'FLCN', 'NAPA', 'GLRB', 'FOXP2',
#          'NPC2', 'PIM3', 'PIM3', 'NDUFS6', 'FOXP2', 'RCCD1', 'MDN1',
#          'UBE2L6', 'NPC2', 'AMPD3', 'CAP1', 'ENO1', 'IRF3', 'TMEM223',
#          'IL13RA1', 'NPC2', 'LRG1', 'JAK2', 'CMPK2', 'CTCF', 'SLC35B4',
#          'METTL17', 'DDIT4', 'CNIH1', 'STAT2', 'ENO1', 'PDRG1', 'NFKBIA',
#          'TNFRSF14', 'UBE2Z', 'GMPPB', 'UBE2Z', 'PELI3', 'GABPA', 'KCTD13',
#          'PIM3', 'KRI1', 'TLR8', 'CPSF2', 'AP001816.1', 'FAT1', 'NLRP3',
#          'NUDCD3', 'PDRG1', 'PYROXD1', 'FLCN', 'XXYLT1', 'ACOT13', 'NARF',
#          'COA1', 'JMJD6', 'ZNF140', 'RP11-166O4.6', 'MT-CYB', 'SPHK2',
#          'CTCF', 'RNASEH1', 'PELI2', 'IRF3', 'CALHM3', 'IFT122', 'PYROXD1',
# ...
